# %%
import pandas as pd
import s3fs
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv('s3://datasets.tomcatling/Untitled spreadsheet - cz_06.csv')

# %%
df.head(3)
# Out:
#   Geographical region Country of previous nationality    1990    1991    1992  \
# 0              *Total                          *Total  57,271  58,642  42,244
# 1        Africa North             *Total Africa North     892   1,631   1,333
# 2  Africa Sub-Saharan       *Total Africa Sub-Saharan   7,255   6,791   4,952
#
#      1993    1994    1995    1996    1997   ...        2008     2009     2010  \
# 0  45,793  44,033  40,516  43,069  37,010   ...     129,377  203,789  195,094
# 1   1,633   1,757   1,607   1,735   1,236   ...       3,102    4,794    4,650
# 2   5,816   6,124   6,330   7,424   6,780   ...      37,847   50,490   46,607
#
#       2011     2012     2013     2014     2015     2016     2017
# 0  177,934  194,370  208,095  125,754  118,109  149,421  123,229
# 1    4,730    4,955    4,458    2,527    2,405    2,895    2,343
# 2   42,146   48,219   43,420   29,275   29,270   34,793   24,228
#
# [3 rows x 30 columns]

# %%
number_cols = list(df.columns)[2:]

# %%
for col in number_cols:
    df[col] = df[col].apply(lambda x:x.replace(',',''))
    df[col] = pd.to_numeric(df[col],downcast='integer',errors='coerce')

# %%
df.head(3)
# Out:
#   Geographical region Country of previous nationality     1990     1991  \
# 0              *Total                          *Total  57271.0  58642.0
# 1        Africa North             *Total Africa North    892.0   1631.0
# 2  Africa Sub-Saharan       *Total Africa Sub-Saharan   7255.0   6791.0
#
#       1992     1993     1994     1995     1996     1997    ...         2008  \
# 0  42244.0  45793.0  44033.0  40516.0  43069.0  37010.0    ...     129377.0
# 1   1333.0   1633.0   1757.0   1607.0   1735.0   1236.0    ...       3102.0
# 2   4952.0   5816.0   6124.0   6330.0   7424.0   6780.0    ...      37847.0
#
#        2009      2010      2011      2012      2013      2014      2015  \
# 0  203789.0  195094.0  177934.0  194370.0  208095.0  125754.0  118109.0
# 1    4794.0    4650.0    4730.0    4955.0    4458.0    2527.0    2405.0
# 2   50490.0   46607.0   42146.0   48219.0   43420.0   29275.0   29270.0
#
#        2016      2017
# 0  149421.0  123229.0
# 1    2895.0    2343.0
# 2   34793.0   24228.0
#
# [3 rows x 30 columns]

# %%
df = df.groupby('Geographical region').sum()

# %%
df = df.transpose()

# %%
df.drop(columns=['*Total'],inplace=True)
df.head()
# Out:
# Geographical region  Africa North  Africa Sub-Saharan  \
# 1990                       1784.0             14510.0
# 1991                       3262.0             13582.0
# 1992                       2666.0              9904.0
# 1993                       3266.0             11632.0
# 1994                       3514.0             12248.0
#
# Geographical region  America Central and South   America North  Asia Central  \
# 1990                                    10748.0         2492.0          30.0
# 1991                                     7600.0         3332.0          84.0
# 1992                                     5112.0         4022.0          64.0
# 1993                                     5314.0         4342.0          64.0
# 1994                                     5038.0         4028.0         138.0
#
# Geographical region  Asia East  Asia South  Asia South East    EU 14   EU 2  \
# 1990                     882.0     42240.0           5666.0  11364.0   32.0
# 1991                    2044.0     39866.0           9904.0   4312.0  100.0
# 1992                    2004.0     23032.0           6678.0   3098.0  122.0
# 1993                    2382.0     26412.0           7340.0   2720.0  152.0
# 1994                    2432.0     24396.0           6384.0   2768.0  246.0
#
# Geographical region    EU 8  EU Other  Europe Other  Middle East  Oceania  \
# 1990                 1048.0    2016.0        2222.0       3848.0   2268.0
# 1991                 2612.0    2286.0        3562.0       7746.0   2472.0
# 1992                 1978.0    1200.0        2648.0       7644.0   2924.0
# 1993                 1796.0    1282.0        3434.0       8664.0   2904.0
# 1994                 1344.0    1080.0        3496.0       8644.0   3078.0
#
# Geographical region    Other
# 1990                 13392.0
# 1991                 14520.0
# 1992                 11392.0
# 1993                  9882.0
# 1994                  9232.0

# %%
df['asia_sum'] = df[[c for c in list(df.columns) if 'asia' in c.lower()]].sum(axis=1)
df['america_sum'] = df[[c for c in list(df.columns) if 'america' in c.lower()]].sum(axis=1)
df['africa_sum'] = df[[c for c in list(df.columns) if 'africa' in c.lower()]].sum(axis=1)
df['EU_sum'] = df[[c for c in list(df.columns) if 'EU' in c or 'EUROPE' in c.upper()]].sum(axis=1)

# %%
plt.figure(figsize=(20,10))

plt.stackplot(range(1990,2018),
              df['asia_sum'], 
              df['america_sum'], 
              df['africa_sum'], 
              df['EU_sum'],
              df['Oceania'],
              df['Other'],
              labels=['Asia','America','Africa','Europe','Oceania','Other'])
plt.legend(fontsize=16)
plt.title('Citizenship Grants by Previous Region of Nationality',fontsize=18)
plt.xlim(1990,2017)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16);
